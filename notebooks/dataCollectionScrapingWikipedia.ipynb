# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import csv

# %% [markdown]
# ## List of central Africa countries to scrape hospitals for

# %%
countries = [
    "Angola",
    "Burundi",
    "Cameroon",
    "Central African Republic",
    "Chad",
    "Democratic Republic of the Congo",
    "Equatorial Guinea",
    "Gabon",
    "Republic of the Congo",
    "Rwanda",
    "São Tomé and Príncipe"
]

# %% [markdown]
# ## Scrap list of hospitals for each central African country

# %%
def getHospitalsListCountry(country_name):
    """
    Fetches a list of hospitals from the Wikipedia page for the specified country.
    
    Parameters:
    - country_name (str): The name of the country to fetch hospitals for.
    
    Returns:
    - list: A list of hospital names.
    """
    # URL
    country_formatted = country_name.replace(' ', '_')
    url = f"https://en.wikipedia.org/wiki/List_of_hospitals_in_{country_formatted}"

    hospitals = []  
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')

        content_blocks = soup.findAll(['table', 'ul'], {'class': ['wikitable', 'toc']})

        for block in content_blocks:
            if block.name == 'table':
                rows = block.findAll('tr')
                for row in rows[1:]:  # Skip the header row
                    first_column = row.find('td')
                    if first_column:
                        hospitals.append(first_column.text.strip())
            elif block.name == 'ul':
                items = block.findAll('li')
                for item in items:
                    hospitals.append(item.text.strip())

    except Exception as e:
        print(f"An error occurred while processing {country_name}: {e}")

    return hospitals

# Loop through the countries and print out the hospitals
for country in countries:
    print(f"Hospitals in {country}:")
    hospitals = get_hospitals_for_country(country)
    if hospitals:
        for hospital in hospitals:
            print(f"- {hospital}")
    else:
        print("No hospitals found or page structure differs.")
    print("\n---\n")
# Out:
# Hospitals in Angola:
# - ('Angola', 'Bongo Mission Hospital')
# - ('Angola', 'Cajueiros General Hospital')
# - ('Angola', 'Clínica Multiperfil')
# - ('Angola', 'Hospital Our Lady of Peace (Nossa Senhora da Paz) (Spanish Wikipedia)')
# - ('Angola', 'Josina Machel Hospital')
# - ('Angola', 'Lucrécia Paím Maternity Hospital')
# - ('Angola', 'Hospital Américo Boavida')
# - ('Angola', 'Hospital Do Prenda')
# - ('Angola', 'Hospital Geral Camama')
# - ('Angola', 'Hospital Geral Kilamba Kiaxi')
# - ('Angola', 'Hospital Municipal de Luanda')
# - ('Angola', 'Hospital Neves Bendinha')
# - ('Angola', 'Hospital Sanatório')
# - ('Angola', 'Consol Provincial de Kuango Kubango')
# - ('Angola', 'Hospital Municipal do Kuvango Municipal')
# - ('Angola', 'Hospital Municipal de Cafunfo')
# - ('Angola', 'Hospital Municipal de Lucapa')
# - ('Angola', 'Hospital Municipal de Nzagi Cambulo')
# - ('Angola', 'Hospital Provincial da Luanda Norte')
# - ('Angola', 'Consol Provincial de Luanda Sul')
# - ('Angola', 'Hospital Barra Do Dande')
# - ('Angola', 'Hospital Dos Dembos')
# - ('Angola', 'Benguela 70 Hospital')
# - ('Angola', 'Caham Hospital')
# - ('Angola', 'Chiulo Hospital')
# - ('Angola', 'Curoca Hospital')
# - ('Angola', 'Cuvelai Hospital')
# - ('Angola', 'Namacunde Hospital')
# - ('Angola', 'Oncocua Hospital')
# - ('Angola', 'Bailundo Hospital')
# - ('Angola', 'Caminho de Ferro de Benguela Hospital')
# - ('Angola', 'Huambo Sanitorio Hospital')
# - ('Angola', 'Agostino Neto Hospital')
# - ('Angola', 'Capelongo Hospital')
# - ('Angola', 'Igreja Evangelica Sinodal de Angola Hospital')
# - ('Angola', 'Kapelongo Hospital')
# - ('Angola', 'Missão Católica-Madre Isabel Hospital')
# - ('Angola', 'Mitcha Hospital')
# - ('Angola', 'P. Zeca Hospital')
# - ('Angola', 'Pioneiro Zeca Hospital')
# - ('Angola', 'Sanatório Hospital Lubango')
# - ('Angola', 'Camucuio Hospital')
# - ('Angola', 'Saco Mar Hospital')
# - ('Angola', 'Sanatório Hospital Moçamedes')
# - ('Angola', 'Uige Sanitorio Hospital')
#
# ---
#
# Hospitals in Burundi:
# - ('Burundi', '2')
# - ('Burundi', '3')
# - ('Burundi', '4')
# - ('Burundi', '5')
# - ('Burundi', '6')
# - ('Burundi', '7')
# - ('Burundi', '8')
# - ('Burundi', '9')
# - ('Burundi', '10')
#
# ---
#
# Hospitals in Cameroon:
# - ('Cameroon', 'Bankim Hôpital de District')
# - ('Cameroon', 'Banyo Hôpital de District')
# - ('Cameroon', 'Baptist Hospital Banyo')
# - ('Cameroon', 'Boumdjere Regional Hôpital')
# - ('Cameroon', "Belel Centre Médical d'Arrondissement")
# - ('Cameroon', "Dang Centre Médical d'Arrondissement")
# - ('Cameroon', "Dibi Centre Médical d'Arrondissement")
# - ('Cameroon', "Dir Centre Médical d'Arrondissement")
# - ('Cameroon', 'Djohong Hôpital de District')
# - ('Cameroon', "Galim-Tignère Centre Médical d'Arrondissement")
# - ('Cameroon', "Kontcha Centre Médical d'Arrondissement")
# - ('Cameroon', "Mayo-Baléo Centre Médical d'Arrondissement")
# - ('Cameroon', "Mayo-Darlé Centre Médical d'Arrondissement")
# - ('Cameroon', "Mbe Centre Médical d'Arrondissement")
# - ('Cameroon', 'Meiganga Hôpital de District')
# - ('Cameroon', 'Ngaoundal Centre Medical d’Arrondissement')
# - ('Cameroon', 'Ngaoundere Hôpital Regional')
# - ('Cameroon', "Nyambaka Centre Médical d'Arrondissement")
# - ('Cameroon', 'Protestant Hospital of Ngaoundéré')
# - ('Cameroon', "Songkolong Centre Médical d'Arrondissement")
# - ('Cameroon', "Tibati Centre Médical d'Arrondissement")
# - ('Cameroon', 'Tignère Hôpital de District')
# - ('Cameroon', 'Akonolinga Hôpital de District')
# - ('Cameroon', 'Awaé Hôpital de District')
# - ('Cameroon', 'Ayos Annex Hôpital Regional')
# - ('Cameroon', 'Bafia Hôpital de District')
# - ('Cameroon', 'Biyem-Assi Hôpital de District')
# - ('Cameroon', 'Cabinet Medicale de La Cathedrale')
# - ('Cameroon', 'Central Hospital of Yaoundé')
# - ('Cameroon', 'Centre Hospitalier et Universitaire de Yaoundé')
# - ('Cameroon', 'Cite Verte Hôpital de District')
# - ('Cameroon', "D'joungolo Hôpital de District")
# - ('Cameroon', 'Ebebda Hôpital de District')
# - ('Cameroon', 'Efoulan Hôpital de District')
# - ('Cameroon', 'Elig-Mfomo Hôpital de District')
# - ('Cameroon', 'Eséka Hôpital de District')
# - ('Cameroon', 'Esse Hôpital de District')
# - ('Cameroon', 'Essos Centre Hospital')
# - ('Cameroon', 'Evodoula Hôpital de District')
# - ('Cameroon', 'Hôpital Général de Yaoundé')
# - ('Cameroon', 'Institute Pasteur (Ritha Moussongi)')
# - ('Cameroon', 'Mbalmayo District Hospital')
# - ('Cameroon', 'Mbandjock Hôpital de District')
# - ('Cameroon', 'Mbankomo Hôpital de District')
# - ('Cameroon', 'Mfou Hôpital de District')
# - ('Cameroon', 'Monatélé Hôpital de District')
# - ('Cameroon', 'Nanga Eboko Hôpital de District')
# - ('Cameroon', 'Ndikiniméki Hôpital de District')
# - ('Cameroon', 'Ngog-Mapubi Hôpital de District')
# - ('Cameroon', 'Ngoumou Hôpital de District')
# - ('Cameroon', 'Nkolndongo District Hospital')
# - ('Cameroon', 'Ntui Hôpital de District')
# - ('Cameroon', 'Obala Hôpital de District')
# - ('Cameroon', 'Olembe Hôpital de District')
# - ('Cameroon', "Sa'a Hôpital de District")
# - ('Cameroon', 'Soa Hôpital de District')
# - ('Cameroon', 'Yaoundé Gynaecology, Obstetrics and Pediatrics Hospital')
# - ('Cameroon', 'Yoko Hôpital de District')
# - ('Cameroon', 'Abong-Mbang Hôpital de District')
# - ('Cameroon', 'Batouri Hôpital de District')
# - ('Cameroon', 'Bertoua Hôpital de District')
# - ('Cameroon', 'Bétaré-Oya Hôpital de District')
# - ('Cameroon', 'Doume Hôpital de District')
# - ('Cameroon', 'Garoua Boulai Hôpital de District')
# - ('Cameroon', 'Kette Hôpital de District')
# - ('Cameroon', 'Lomie Hôpital de District')
# - ('Cameroon', 'Mbang Hôpital de District')
# - ('Cameroon', 'Messamena Hôpital de District')
# - ('Cameroon', 'Moloundou Hôpital de District')
# - ('Cameroon', 'Ndelele Hôpital de District')
# - ('Cameroon', 'Nguelemendouka Hôpital de District')
# - ('Cameroon', 'Yokadouma Hôpital de District')
# - ('Cameroon', 'Bonamoussadi Ad Lucem Hôpital de District')
# - ('Cameroon', 'Bonassama Hôpital de District')
# - ('Cameroon', 'Chinese Hospital')
# - ('Cameroon', 'Cite Des Palmiers Hôpital de District')
# - ('Cameroon', 'Deido Hôpital de District')
# - ('Cameroon', 'Dibombari Hôpital de District')
# - ('Cameroon', 'Douala Hôpital General')
# - ('Cameroon', 'Edéa Hôpital Regional')
# - ('Cameroon', 'Ekol-Mbeng Hôpital Regional')
# - ('Cameroon', 'Laquintinie Hospital')
# - ('Cameroon', 'Logbaba Hôpital de District')
# - ('Cameroon', 'Loum Hôpital de District')
# - ('Cameroon', 'Manjo Hôpital de District')
# - ('Cameroon', 'Manoka Hôpital de District')
# - ('Cameroon', 'Mbanga Hôpital de District')
# - ('Cameroon', 'Mboppi Baptist Hospital')
# - ('Cameroon', 'Melong Hôpital de District')
# - ('Cameroon', 'Ndom Hôpital de District')
# - ('Cameroon', 'New Bell Hôpital de District')
# - ('Cameroon', 'Ngambé Hôpital de District')
# - ('Cameroon', 'Nkondjock Hôpital de District')
# - ('Cameroon', 'Nylon Hôpital de District')
# - ('Cameroon', 'Polyclinique BonanjoDaniel Muna Memorial Clinic')
# - ('Cameroon', 'Pouma Hôpital de District')
# - ('Cameroon', 'Presbyterian Health Complex Douala')
# - ('Cameroon', 'Yabassi Hôpital de District')
# - ('Cameroon', 'Bibemi Hôpital de District')
# - ('Cameroon', 'Figuil Hôpital de District')
# - ('Cameroon', 'Garoua Hôpital de District')
# - ('Cameroon', 'Garoua Hôpital Regional')
# - ('Cameroon', 'Gaschiga Hôpital de District')
# - ('Cameroon', 'Guider Hôpital de District')
# - ('Cameroon', 'Lagdo Hôpital de District')
# - ('Cameroon', 'M Hôpital de District')
# - ('Cameroon', 'Mayo-Oulo Hôpital de District')
# - ('Cameroon', 'Ngong Hôpital de District')
# - ('Cameroon', 'Pitoa Hôpital de District')
# - ('Cameroon', 'Poli Hôpital de District')
# - ('Cameroon', 'Rey Bouba Hôpital de District')
# - ('Cameroon', 'Tcholliré Hôpital de District')
# - ('Cameroon', 'Touboro Hôpital de District')
# - ('Cameroon', 'Maroua Hôpital Regional')
# - ('Cameroon', 'Yagoua Hôpital Regional')
# - ('Cameroon', 'Annexe de Kousséri Hôpital Regional')
# - ('Cameroon', 'Bogo Hôpital de District')
# - ('Cameroon', 'Bourha Hôpital de District')
# - ('Cameroon', 'Doukoula Hôpital de District')
# - ('Cameroon', 'Goulfey Hôpital de District')
# - ('Cameroon', 'Guere Hôpital de District')
# - ('Cameroon', 'Guidiguis Hôpital de District')
# - ('Cameroon', 'Hina Hôpital de District')
# - ('Cameroon', 'Hôpital Cemao de Meskine')
# - ('Cameroon', 'Kaélé Hôpital de District')
# - ('Cameroon', 'Kar Hay Hôpital de District')
# - ('Cameroon', 'Kousséri Hôpital de District')
# - ('Cameroon', 'Mada Hôpital de District')
# - ('Cameroon', 'Makary Hôpital de District')
# - ('Cameroon', 'Mindif Hôpital de District')
# - ('Cameroon', 'Mogode Hôpital de District')
# - ('Cameroon', 'Mokolo Hôpital de District')
# - ('Cameroon', 'Mora Hôpital de District')
# - ('Cameroon', 'Moulvoudaye Hôpital de District')
# - ('Cameroon', 'Moutourwa Hôpital de District')
# - ('Cameroon', 'Petté Hôpital de District')
# - ('Cameroon', 'Roua Hôpital de District')
# - ('Cameroon', 'Tokombéré Hôpital de District')
# - ('Cameroon', 'Vele Hôpital de District')
# - ('Cameroon', 'Ako Hôpital de District')
# - ('Cameroon', 'Bafut Hôpital de District')
# - ('Cameroon', 'Bali Hôpital de District')
# - ('Cameroon', 'Bamenda Regional Hospital')
# - ('Cameroon', 'Baptist Hospital Banso')
# - ('Cameroon', 'Bawock Health District Hospital')
# - ('Cameroon', 'Benakuma District Hospital')
# - ('Cameroon', 'Dunger Baptist Hospital')
# - ('Cameroon', 'Fundong Hôpital de District')
# - ('Cameroon', 'Grace Gardens Hospital Ndop')
# - ('Cameroon', 'Mbengwi Hôpital de District')
# - ('Cameroon', 'Mbingo Baptist Hospital')
# - ('Cameroon', 'Ndop Hôpital de District')
# - ('Cameroon', 'Ndu District Hospital')
# - ('Cameroon', 'Nduh Hôpital de District')
# - ('Cameroon', 'Njikwa Hôpital de District')
# - ('Cameroon', 'Nkambé Hôpital de District')
# - ('Cameroon', 'Nwa Hôpital de District')
# - ('Cameroon', 'Oku Hôpital de District')
# - ('Cameroon', 'PMI Medicalized Health Center Nkwen')
# - ('Cameroon', 'Presbyterian General Hospital Acha-Tugi')
# - ('Cameroon', 'Presbyterian Health Centre Bafut')
# - ('Cameroon', 'Santa Hôpital de District')
# - ('Cameroon', 'St. Elizabeth Catholic General Hospital Shisong')
# - ('Cameroon', 'St Martin de porress Catholic General hospital')
# - ('Cameroon', 'Tubah Hôpital de District')
# - ('Cameroon', 'Wum Hôpital de District')
# - ('Cameroon', 'Yang  Health Center')
# - ('Cameroon', 'Ambam Hôpital de District')
# - ('Cameroon', 'Djoum Hôpital de District')
# - ('Cameroon', 'Ebolowa Regional Hospital')
# - ('Cameroon', 'Enongal Hôpital Central')
# - ('Cameroon', 'Kribi Hôpital de District')
# - ('Cameroon', 'Lolodorf Hôpital de District')
# - ('Cameroon', 'Mekomengona District Hôpital de District')
# - ('Cameroon', 'Meyomessala Hôpital de District')
# - ('Cameroon', 'Mvangan Hôpital de District')
# - ('Cameroon', 'Olamze Hôpital de District')
# - ('Cameroon', 'Sangmélima Hôpital de District')
# - ('Cameroon', 'Zoetele Hôpital de District')
# - ('Cameroon', 'Baptist Hospital Mutengene')
# - ('Cameroon', 'Buea Regional Hospital')
# - ('Cameroon', 'Christ Medical Center')
# - ('Cameroon', 'Ejed Medical Foundation Hospital')
# - ('Cameroon', 'Hope Clinic')
# - ('Cameroon', 'Kumba District Hospital')
# - ('Cameroon', 'Limbe Regional Hospital')
# - ('Cameroon', 'Mamfe Hôpital de District')
# - ('Cameroon', 'Mary Health of Africa')
# - ('Cameroon', 'Mbonge Hôpital de District')
# - ('Cameroon', 'Presbyterian Medical Institutions Manyemen')
# - ('Cameroon', 'Mundemba Hôpital de District')
# - ('Cameroon', 'Muyuka Hôpital de District')
# - ('Cameroon', 'Presbyterian Health Complex, Kumba')
# - ('Cameroon', 'Presbyterian Hospital Nyasoso')
# - ('Cameroon', 'Redemption Medical Foundation')
# - ('Cameroon', 'Solidarity Clinic')
# - ('Cameroon', 'St. John of God Hospital')
# - ('Cameroon', "St Joseph's Medical Center")
# - ('Cameroon', 'Subdivisional Hospital')
# - ('Cameroon', 'Tiko Hôpital de District')
# - ('Cameroon', 'Tombel Hôpital de District')
# - ('Cameroon', 'ACHA Foundation Clinic of Bafoussam')
# - ('Cameroon', 'Bafoussam Baptist Hospital')
# - ('Cameroon', 'Bafoussam Regional Hospital')
# - ('Cameroon', 'Hôpital de District de Bafang')
# - ('Cameroon', 'Hôpital de District de Bandja')
# - ('Cameroon', 'Hôpital de District de Bamendjou')
# - ('Cameroon', 'Hôpital de District de Bangangté')
# - ('Cameroon', 'Hôpital de District de Bandjoun')
# - ('Cameroon', 'Hôpital de District de Bangourain')
# - ('Cameroon', 'Hôpital de District de Batcham')
# - ('Cameroon', 'Hôpital de District de Dschang')
# - ('Cameroon', 'Hôpital de District de Foumban')
# - ('Cameroon', 'Hôpital de District de Foumbot')
# - ('Cameroon', 'Hôpital de District de Galim')
# - ('Cameroon', 'Hôpital de District de Kékem')
# - ('Cameroon', 'Hôpital de District de Kouoptamo')
# - ('Cameroon', 'Hôpital de District de Malantouen')
# - ('Cameroon', 'Hôpital de District de Massangam')
# - ('Cameroon', 'Hôpital de District de Mbouda')
# - ('Cameroon', 'Hôpital de District de Penka Michel')
# - ('Cameroon', 'Hôpital de District de Santchou')
#
# ---
#
# Hospitals in Central African Republic:
# No hospitals found or page structure differs.
#
# ---
#
# Hospitals in Chad:
# No hospitals found or page structure differs.
#
# ---
#
# Hospitals in Democratic Republic of the Congo:
# No hospitals found or page structure differs.
#
# ---
#
# Hospitals in Equatorial Guinea:
# - ('Equatorial Guinea', 'San Antonio de pale Hospital')
# - ('Equatorial Guinea', 'Bioko Norte 1')
# - ('Equatorial Guinea', 'Bioko Norte 2')
# - ('Equatorial Guinea', 'Bioko Norte 3')
# - ('Equatorial Guinea', 'Bioko Norte 4')
# - ('Equatorial Guinea', 'Bioko Sur 1')
# - ('Equatorial Guinea', 'Centro Sur 1')
# - ('Equatorial Guinea', 'Centro Sur 2')
# - ('Equatorial Guinea', 'Centro Sur 3')
# - ('Equatorial Guinea', 'Centro Sur 4')
# - ('Equatorial Guinea', 'Aconibe District Hospital')
# - ('Equatorial Guinea', 'Akurenam District Hospital')
# - ('Equatorial Guinea', 'Anisok District Hospital')
# - ('Equatorial Guinea', 'Bata Public Regional Hospital')
# - ('Equatorial Guinea', 'Cogo District Hospital')
# - ('Equatorial Guinea', 'Ebebiyin Provincial Hospital')
# - ('Equatorial Guinea', 'Evinayong Provincial Hospital')
# - ('Equatorial Guinea', 'Malabo Public Regional Hospital')
# - ('Equatorial Guinea', 'Mbini District Hospital')
# - ('Equatorial Guinea', 'Mikomeseng District Hospital')
# - ('Equatorial Guinea', 'Mongomo Provincial Hospital')
# - ('Equatorial Guinea', 'Niefang District Hospital')
# - ('Equatorial Guinea', 'Nsoc Nsomo District Hospital')
# - ('Equatorial Guinea', 'Nsork District Hospital')
# - ('Equatorial Guinea', 'Kientem 1')
# - ('Equatorial Guinea', 'Kientem 2')
# - ('Equatorial Guinea', 'Kientem 3')
# - ('Equatorial Guinea', 'Kientem 4')
# - ('Equatorial Guinea', 'Kientem 5')
# - ('Equatorial Guinea', 'Kientem 6')
# - ('Equatorial Guinea', 'Kientem 7')
# - ('Equatorial Guinea', 'Kientem 8')
# - ('Equatorial Guinea', 'Litoral 1')
# - ('Equatorial Guinea', 'Litoral 2')
# - ('Equatorial Guinea', 'Litoral 3')
# - ('Equatorial Guinea', 'Litoral 4')
# - ('Equatorial Guinea', 'Litoral 5')
# - ('Equatorial Guinea', 'Litoral 6')
# - ('Equatorial Guinea', 'Baney District Hospital')
# - ('Equatorial Guinea', 'Luba Provincial Hospital')
# - ('Equatorial Guinea', 'Riaba District Hospital')
# - ('Equatorial Guinea', 'Welenzas 1')
# - ('Equatorial Guinea', 'Welenzas 2')
# - ('Equatorial Guinea', 'Welenzas 3')
# - ('Equatorial Guinea', 'Welenzas 4')
# - ('Equatorial Guinea', 'Welenzas 5')
# - ('Equatorial Guinea', 'Welenzas 6')
#
# ---
#
# Hospitals in Gabon:
# - ('Gabon', '1990')
# - ('Gabon', '2000')
# - ('Gabon', '2021')
# - ('Gabon', 'SDG3 2030\ntargets')
# - ('Gabon', 'George Rawiri Hospitalier Regional')
# - ('Gabon', 'Koulamoutou Centre Hospitalier Urbain')
# - ('Gabon', 'Paul Moukambi Hospitalier Regional')
# - ('Gabon', 'Mouila Hospitalier Regional')
# - ('Gabon', 'Bongolo Hospital')
# - ('Gabon', 'Makokou Hospitalier Regional')
# - ('Gabon', 'Agondje Centre Hospitalier Universitaire')
# - ('Gabon', 'Egypto Gabonaise Hopital Cooperation')
# - ('Gabon', 'Libreville Centre Hospitalier Universitaire')
# - ('Gabon', 'Sino Gabonaise Hopital Cooperation Libreville')
# - ('Gabon', 'Hôpital d’Instruction des Armées Omar Bongo Ondimba')
# - ('Gabon', 'Port Gentil Centre Hospitalier Regional')
# - ('Gabon', 'Port Gentil Hospitalier Regional')
# - ('Gabon', 'Oyem Hospitalier Regional')
# - ('Gabon', 'Benjamin Ngoubou Hospitalier Regional')
# - ('Gabon', 'Tchibanga Hospitalier Regional')
# - ('Gabon', 'Amissa Bongo Hospitalier Regional')
# - ('Gabon', 'Sino Gabonaise Hopital Cooperation Mpassa')
# - ('Gabon', 'Hôpital Albert Schweitzer')
#
# ---
#
# Hospitals in Republic of the Congo:
# No hospitals found or page structure differs.
#
# ---
#
# Hospitals in Rwanda:
# No hospitals found or page structure differs.
#
# ---
#
# Hospitals in São Tomé and Príncipe:
# No hospitals found or page structure differs.
#
# ---

# %% [markdown]
# ## Scrap countries and combine them with list of hospitals scraped into a csv

# %%
def getHospitalsPerCountry(country_name):
    """
    Fetches a list of hospitals from the Wikipedia page for the specified country.
    
    Parameters:
    - country_name (str): The name of the country to fetch hospitals for.
    
    Returns:
    - list of tuples: A list of tuples containing the country name and a hospital name.
    """
    country_formatted = country_name.replace(' ', '_')
    url = f"https://en.wikipedia.org/wiki/List_of_hospitals_in_{country_formatted}"
    hospitals = []

    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        content_blocks = soup.findAll(['table', 'ul'], {'class': ['wikitable', 'toc']})

        for block in content_blocks:
            if block.name == 'table':
                rows = block.findAll('tr')
                for row in rows[1:]:
                    first_column = row.find('td')
                    if first_column:
                        hospitals.append((country_name, first_column.text.strip()))
            elif block.name == 'ul':
                items = block.findAll('li')
                for item in items:
                    hospitals.append((country_name, item.text.strip()))
    except Exception as e:
        print(f"An error occurred while processing {country_name}: {e}")

    return hospitals

# Aggregate hospitals for countries
all_hospitals = []
for country in countries:
    all_hospitals.extend(get_hospitals_for_country(country))

# Write results to a CSV file
csv_hospitals = "hospitals_list.csv"
with open(csv_hospitals, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["Country", "Hospital Name"])
    writer.writerows(all_hospitals)

print(f"Scraping complete. Results saved to {csv_hospitals}.")
# Out:
# Scraping complete. Results saved to hospitals_list.csv.

# %%
df_hospitals = pd.read_csv(csv_hospitals)
print(df_hospitals)
# Out:
#     Country                                      Hospital Name
# 0    Angola                             Bongo Mission Hospital
# 1    Angola                         Cajueiros General Hospital
# 2    Angola                                Clínica Multiperfil
# 3    Angola  Hospital Our Lady of Peace (Nossa Senhora da P...
# 4    Angola                             Josina Machel Hospital
# ..      ...                                                ...
# 341   Gabon              Benjamin Ngoubou Hospitalier Regional
# 342   Gabon                     Tchibanga Hospitalier Regional
# 343   Gabon                  Amissa Bongo Hospitalier Regional
# 344   Gabon          Sino Gabonaise Hopital Cooperation Mpassa
# 345   Gabon                          Hôpital Albert Schweitzer
#
# [346 rows x 2 columns]

# %% [markdown]
# ## Scrap countries per medical facilities and population

# %%
url = "https://en.wikipedia.org/wiki/Lists_of_hospitals_in_Africa"

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# find the first wikitable on the url
table = soup.find('table', {'class': 'wikitable'})

if table is None:
    print("Table not found. Check the class name or structure of the webpage.")
else:
    data = []

    # Iterate over each row in the table, skipping the header
    for row in table.find_all('tr')[1:]:
        cols = row.find_all('td')
        if cols:
            country_name = cols[0].text.strip()
            # medical facilities is located in the fourth column
            facilities = cols[3].text.strip().replace(',', '')
            # Population
            population = cols[4].text.strip().replace(',', '')
            
            if country_name in countries:
                data.append([country_name, facilities, population])

    # Write to CSV
    csv_mfp = 'medical_facilities_population.csv'
    with open(csv_mfp, 'w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['Country', 'Medical Facilities', 'Population (1,000)'])
        writer.writerows(data)

    print(f'Data successfully saved to {csv_mfp}.')
# Out:
# Data successfully saved to medical_facilities_population.csv.

# %%
df_mfp = pd.read_csv(csv_mfp)
print(df_mfp)
# Out:
#                              Country  Medical Facilities  Population (1,000)
# 0                             Angola                1575               24383
# 1                            Burundi                 665                9824
# 2                           Cameroon                3061               21918
# 3           Central African Republic                 555                3859
# 4                               Chad                1283               11040
# 5   Democratic Republic of the Congo               14586              102561
# 6              Republic of the Congo                 328                3697
# 7                  Equatorial Guinea                  47                1222
# 8                              Gabon                 542                1802
# 9                             Rwanda                 572               10516
# 10             São Tomé and Príncipe                  50                 202
